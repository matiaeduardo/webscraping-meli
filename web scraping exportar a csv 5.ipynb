# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
#definir url
url='https://pokemondb.net/pokedex/all'
r=requests.get(url)

# %%
#convertir en sopa
soup=bs(r.content,'html.parser')

# %%
#buscar
rows=soup.find('table',attrs={'id':'pokedex'}).find('tbody').find_all('tr')

# %%
#buscar
rows[0].find_all('td')[1].get_text()
# Out:
# 'Grass Poison'

# %%
#definir las filas
names=[]
escribe=[]
total=[]
hp=[]
ataque=[]
defensa=[]
esp=[]
esp_d=[]
vel=[]
for row in rows:
    names.append(row.find_all('td')[1].get_text())
    escribe.append(row.find_all('td')[2].get_text())
    total.append(row.find_all('td')[3].get_text())
    hp.append(row.find_all('td')[4].get_text())
    ataque.append(row.find_all('td')[5].get_text())
    defensa.append(row.find_all('td')[6].get_text())
    esp.append(row.find_all('td')[7].get_text())
    esp_d.append(row.find_all('td')[8].get_text())
    vel.append(row.find_all('td')[9].get_text())

# %%
#armar el dataframe 
pokedex_df=pd.DataFrame({'nombre':names,
                         'tipo':escribe,
                         'total':total,
                         'hp':hp,
                         'ataque':ataque,
                         'defensa':defensa,
                         'especial ataque':esp,'especial defensa':esp_d,'velocidad':vel})

# %%
pokedex_df
# Out:
#                         nombre             tipo total   hp ataque defensa  \
# 0                    Bulbasaur     Grass Poison   318   45     49      49
# 1                      Ivysaur     Grass Poison   405   60     62      63
# 2                     Venusaur     Grass Poison   525   80     82      83
# 3       Venusaur Mega Venusaur     Grass Poison   625   80    100     123
# 4                   Charmander            Fire    309   39     52      43
# ...                        ...              ...   ...  ...    ...     ...
# 1070        Basculegion Female      Water Ghost   530  120     92      65
# 1071                  Sneasler  Poison Fighting   510   80    130      60
# 1072                  Overqwil      Dark Poison   510   85    115      95
# 1073  Enamorus Incarnate Forme     Fairy Flying   580   74    115      70
# 1074    Enamorus Therian Forme     Fairy Flying   580   74    115     110
#
#      especial ataque especial defensa velocidad
# ...

# %%
#exportar a csv
pokedex_df.to_csv('pokedex_csv.csv')
